# %% [markdown]
# # Actividad
#
# - **Nombre**: David Sanchez
# - **Matrícula**: A01720476
#
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Todas las tareas entregadas fuera de la fecha limite se califican sobre 50 de los 100 puntos posibles.

# %% [markdown]
# 1. Leer el archivo **netflix_titles.csv**

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('Se cargó el archivo: "{name}" con una longitud de {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-58284925-e87e-4af8-8334-a8ee8147b1a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58284925-e87e-4af8-8334-a8ee8147b1a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving netflix_titles.csv to netflix_titles.csv
# Se cargó el archivo: "netflix_titles.csv" con una longitud de 3000491 bytes

# %% [markdown]
# 2. Observa las primeras líneas usando la función head

# %%
import pandas as pd
import io

df = pd.read_csv(io.StringIO(uploaded['netflix_titles.csv'].decode('utf-8')))
df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %% [markdown]
# 3. Genera una función que despliegue el primer reglon del archivo.

# %%
## Esta función debe de regresar una lista con los valores del primer reglon
def top_uno(df):
  return df.head(1)

top_uno(df)
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
#
# [1 rows x 12 columns]

# %% [markdown]
# 4. Genera una función que regrese el número de registros del archivo

# %%
## Esta función tiene que entregar el número de registros del archivo
def top_uno(df):
  index = df.index
  number_of_rows = len(index)
  return number_of_rows

top_uno(df)
# Out:
# 7787

# %% [markdown]
# 5. Generar una función que entregue las películas con release_year del 2020

# %%
## Esta función tiene que entregar las películas creadas en el año 2020

year_consulta=2020
def released_year(year,df):
  return df[df.release_year == year] 

released_year(year_consulta,df)
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 24       s25  ...  Seiya and the Knights of the Zodiac rise again...
# 26       s27  ...  This docuseries takes a deep dive into the luc...
# 27       s28  ...  As a grisly virus rampages a city, a lone man ...
# 29       s30  ...  Kenya Barris and his family navigate relations...
# ...      ...  ...                                                ...
# 7725   s7726  ...  A nurse and her daughter flee her husband’s dr...
# 7734   s7735  ...  An ad creative and a successful exec have a gr...
# 7738   s7739  ...  An incendiary hate crime stirs civil unrest, f...
# 7741   s7742  ...  In 1987, as martial law ends in Taiwan, Jia-ha...
# 7744   s7745  ...  Revisiting life goals set in a letter written ...
#
# [868 rows x 12 columns]

# %% [markdown]
# 6. Películas con la columna de contry='Mexico'

# %%
## Esta función tiene que entregar las películas creadas en Mexico
pais_consulta='Mexico'

def country_year(pais_consulta, df):
  return df[df.country == pais_consulta]

country_year(pais_consulta, df)
# Out:
#      show_id  ...                                        description
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 12       s13  ...  Archival video and new interviews examine Mexi...
# 292     s293  ...  Three lifelong friends travel to Acapulco oste...
# 370     s371  ...  Mexican comic Alan Saldaña has fun with everyt...
# 378     s379  ...  Comic Alex Fernández performs his familiar aut...
# ...      ...  ...                                                ...
# 7698   s7699  ...  On the run from the police, an Arizona man cro...
# 7725   s7726  ...  A nurse and her daughter flee her husband’s dr...
# 7734   s7735  ...  An ad creative and a successful exec have a gr...
# 7773   s7774  ...  This introspective rockumentary follows the ca...
# 7779   s7780  ...  An assortment of talent takes the stage for a ...
#
# [100 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd TEC/5to\ Semestre/Semana\ Tec/Herramientas/SemanaTec/
# Out:
# [Errno 2] No such file or directory: 'TEC/5to Semestre/Semana Tec/Herramientas/SemanaTec/arte-analitica'
# /content/drive/My Drive/TEC/5to Semestre/Semana Tec/Herramientas/SemanaTec

# %%
# %cd arte-analitica
# Out:
# /content/drive/My Drive/TEC/5to Semestre/Semana Tec/Herramientas/SemanaTec/arte-analitica

# %%
# Vamos a importar el archivo y leer los contenidos.
import json

# Lectura del archivo
with open('credenciales.json', 'r') as myfile:
    data = myfile.read()

# Leer el formato del archivo
obj = json.loads(data)

# Vamos a guardar los datos en estas variables
GIT_USERNAME = obj['user']

# token
GIT_TOKEN = obj['token']

# Repo
GIT_REPO = obj['repo']

# Creamos la ruta al repositorio de nuestra cuenta
GIT_PATH = "https://" + GIT_USERNAME + ":" + GIT_TOKEN + "@github.com/" +\
            GIT_USERNAME + "/" + GIT_REPO + ".git"

# %%
# !git config --global user.email "A01720476@itesm.mx"

# %%
# !git config --global user.name "David Sanchez"

# %%
# !git add *
